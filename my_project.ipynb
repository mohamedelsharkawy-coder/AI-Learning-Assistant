# %%
from crewai import Agent, Task, Crew, Process, LLM
from crewai.tools import tool
from pydantic import BaseModel, Field
from typing import List
from tavily import TavilyClient
import os

# %%
os.environ["GEMINI_API_KEY"] = "AIzaSyDJF_6G6ahe5l4fAl2dJnigJ9RC8TtjXi0"
basic_llm = LLM(model="gemini/gemini-1.5-flash", temperature=0)
search_client = TavilyClient(api_key="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")

# %%
# make dir to put the final output in
output_dir = "./ai-agent-output"
os.makedirs(output_dir, exist_ok=True)

# define the max number of results 
results_num = 5

# %% [markdown]
# ## Setup Agents

# %% [markdown]
# ### Agent: A

# %%
class SuggestedSearchQueries(BaseModel):
    queries: List[str] = Field(..., title="Suggested search queries to help the user self-learn a topic",
                               min_items=1, max_items=10)

search_queries_recommendation_agent = Agent(
    role="Search Queries Recommendation Agent",
    goal="\n".join([
        "Generate a list of well-structured and general-purpose search queries based on a given learning topic and user level.",
        "Queries should be informative, specific, and useful for self-learning.",
        "Do not include the name of any platform, website, or content type.",
        "The goal is to create queries that can be used in general-purpose search engines."
    ]),
    backstory=(
        "This agent helps learners by generating highly relevant search queries for any topic and skill level. "
        "It avoids mentioning specific sources, allowing downstream agents to handle targeted search in different content formats."
    ),
    llm=basic_llm,
    verbose=True
)

search_queries_recommendation_task = Task(
    description="\n".join([
        "The user is interested in learning about: {topic_name}",
        "Their current skill level is: {learning_level} (beginner, intermediate, or advanced).",
        f"Generate up to 10 clear, focused, and diverse search queries.",
        "These queries should be general and not include any source/platform names (e.g., avoid YouTube, Coursera, GitHub, etc.).",
        "Incorporate the learning level implicitly into the query wording (e.g., 'beginner guide to ...', 'advanced concepts in ...').",
        "Avoid vague or overly broad phrases; be precise while keeping queries adaptable for different formats.",
        "Keep the phrasing natural, as a human would search in a general search engine."
    ]),
    expected_output="A JSON object containing a list of suggested general-purpose search queries.",
    output_json=SuggestedSearchQueries,
    output_file=os.path.join(output_dir, "step_1_suggested_search_queries.json"),
    agent=search_queries_recommendation_agent
)

# %% [markdown]
# ### Agent: B

# %%
class SingleSearchResult(BaseModel):
    title: str
    url: str = Field(..., title="The page URL")

class AllSearchResults(BaseModel):
    results: List[SingleSearchResult]

# Tool to perform a filtered visual learning search
@tool
def visual_search_tool(query: str) -> List[SingleSearchResult]:
    """ Searches only within  for visual resources"""
    youtube_query = search_client.search(query=query+"site:youtube.com", max_results=results_num)
    udemy_query = search_client.search(query="free"+query+"site:udemy.com", max_results=results_num)
    coursera_query = search_client.search(query="free"+query+"site:coursera.org", max_results=results_num)
    
    return [youtube_query, udemy_query, coursera_query]

# Define the agent
visual_search_agent = Agent(
    role="Visual Learning Resources Agent",
    goal="To find visual educational resources (videos, playlists, courses) based on given search queries.",
    backstory="You specialize in finding helpful video-based learning materials for advanced learners from YouTube, Coursera, Udemy, and Khan Academy.",
    llm=basic_llm,
    verbose=True,
    tools=[visual_search_tool]
)

# Define the task
visual_search_task = Task(
    description="\n".join([
    "Use the provided general search queries to find ONLY visual educational resources.",
    "Search exclusively within YouTube, Coursera, and Udemy. Ignore other sources.",
    "Make sure to retrieve 5 links from each website [youtube.com, udemy.com, coursera.org]",
    "Exclude any non-visual resources such as blog posts, PDFs, GitHub repos, or written research papers.",
    "Return only video links, playlists, or course landing pages with high educational value.",
    "Ensure all results are relevant to the query and tailored to learners at the '{learning_level}' level.",
    "Results should be clear, informative, and suitable for visual learning formats."
]),
    expected_output="A JSON file containing valid visual search results.",
    output_json=AllSearchResults,
    output_file=os.path.join(output_dir, "step_2_visual_results.json"),
    agent=visual_search_agent
)

# %% [markdown]
# ### Agent: C

# %%
class SingleSearchResult(BaseModel):
    title: str
    url: str = Field(..., title="The page URL")

class AllSearchResults(BaseModel):
    results: List[SingleSearchResult]

@tool
def text_search_tool(query: str) -> List[SingleSearchResult]:
    """ Searches only within medium.com, arxiv.org, github.com, paperswithcode.com, distill.pub for text resources"""
    medium_query = search_client.search(query=query+"site:medium.com", max_results=results_num)
    arxiv_query = search_client.search(query=query+"site:arxiv.org", max_results=results_num)
    github_query = search_client.search(query=query+"site:github.com", max_results=results_num)
    paperswithcode_query = search_client.search(query=query+"site:paperswithcode.com", max_results=results_num)
    return [medium_query, arxiv_query, github_query, paperswithcode_query]



# Define the agent
text_search_agent = Agent(
    role="Textual Learning Resources Agent",
    goal="To find rich, insightful, and trustworthy educational resources from top-tier domains.",
    backstory="You're a research assistant who specializes in discovering valuable content like articles, GitHub repos, research papers, and technical blogs from well-known educational platforms.",
    llm=basic_llm,
    verbose=True,
    tools=[text_search_tool]
)

# Define the task
text_search_task = Task(
    description="\n".join([
    "Use the available search tools to find **educational resources** related to a given query.",
    "Each tool searches **only within a trusted domain** (e.g., Medium, arXiv, GitHub, PapersWithCode, Distill).",
    "Make sure to retrieve 5 links from each website [medium.com, arxiv.org, github.com, paperswithcode.com, distill.pub]",
    "Focus on text-based, high-quality results such as: blog posts, technical articles, GitHub repositories, and academic papers.",
    "Avoid video-based content entirely (e.g., YouTube, Coursera, Udemy).",
    "Ensure that the results are relevant and valuable to the level of user which {learning_level}",
    "Return **at least 5 relevant results** per query if possible.",
    "Each result must include a title and a working URL.",
]),
    expected_output="A JSON file with the best educational search results.",
    output_json=AllSearchResults,
    output_file=os.path.join(output_dir, "step_3_textual_results.json"),
    agent=text_search_agent
)

# %% [markdown]
# ### Agent: D

# %%
summary_markdown_agent = Agent(
    role="Markdown Learning Report Designer",
    goal="Create a clean, structured Markdown (.md) report from visual and textual sources.",
    backstory=(
        "This agent builds a clean Markdown summary from visual and textual learning sources. "
        "The format is simple, readable, and structured with bullet points for easy navigation."
    ),
    llm=basic_llm,
    verbose=True,
)

summary_markdown_task = Task(
    description="\n".join([
        "Create a fully structured Markdown (.md) report file that contains all visual and textual learning resources.",
        "Structure should be:",
        "1. Centered Title: 'Summary Report' (use markdown heading)",
        "2. Visual Resources Section:",
        "- List each visual result from the agent (Visual Learning Resources Agent) as a bullet point like this: [Title](URL)",
        "3. Textual Resources Section:",
        "- List each textual result from the agent (Textual Learning Resources Agent) as a bullet point like this: [Title](URL)",
        "Important Notes:",
        "- Do NOT include any HTML tags.",
        "- Do NOT include any code blocks like ```.",
        "- The file should be clean Markdown only, without any extra formatting.",
    ]),
    expected_output="A structured Markdown file with all links.",
    output_file=os.path.join(output_dir, "summary_report.md"),
    agent=summary_markdown_agent,
)

# %% [markdown]
# ## Run the AI Crew

# %%
flow = Crew(
    agents=[
        search_queries_recommendation_agent,
        visual_search_agent,
        search_queries_recommendation_agent,
        text_search_agent,
        summary_markdown_agent
    ],
    
    tasks=[
        search_queries_recommendation_task,
        visual_search_task,
        search_queries_recommendation_task,
        text_search_task,
        summary_markdown_task
    ],
    
    process=Process.sequential
)

# %%
flow.kickoff(
    inputs={
        'topic_name':"Data Science",
        'learning_level':'Intermediate'
    }
)
# Out:
# # Agent: Search Queries Recommendation Agent
# ## Task: The user is interested in learning about: Data Science
# Their current skill level is: Intermediate (beginner, intermediate, or advanced).
# Generate up to 10 clear, focused, and diverse search queries.
# These queries should be general and not include any source/platform names (e.g., avoid YouTube, Coursera, GitHub, etc.).
# Incorporate the learning level implicitly into the query wording (e.g., 'beginner guide to ...', 'advanced concepts in ...').
# Avoid vague or overly broad phrases; be precise while keeping queries adaptable for different formats.
# Keep the phrasing natural, as a human would search in a general search engine.
#
#
# # Agent: Search Queries Recommendation Agent
# ## Final Answer:
# {
#   "queries": [
#     "intermediate data science projects with python",
#     "practical applications of machine learning for data science",
#     "data visualization techniques for intermediate data scientists",
#     "mastering data manipulation with pandas for intermediate users",
#     "building predictive models using scikit-learn: intermediate tutorial",
#     "handling imbalanced datasets in data science: intermediate solutions",
#     "intermediate data science: a focus on model evaluation metrics",
#     "common pitfalls in intermediate data science projects and how to avoid them",
#     "statistical modeling techniques for intermediate data scientists",
#     "deploying machine learning models: an intermediate guide"
#   ]
# }
#
#
# # Agent: Visual Learning Resources Agent
# ## Task: Use the provided general search queries to find ONLY visual educational resources.
# Search exclusively within YouTube, Coursera, and Udemy. Ignore other sources.
# Make sure to retrieve 5 links from each website [youtube.com, udemy.com, coursera.org]
# Exclude any non-visual resources such as blog posts, PDFs, GitHub repos, or written research papers.
# Return only video links, playlists, or course landing pages with high educational value.
# Ensure all results are relevant to the query and tailored to learners at the 'Intermediate' level.
# Results should be clear, informative, and suitable for visual learning formats.
#
#
# # Agent: Visual Learning Resources Agent
# ## Thought: Thought:I need to use the `visual_search_tool` to search for visual learning resources on YouTube, Coursera, and Udemy for each query provided.  I will then format the results into the required JSON structure.
# ## Using tool: visual_search_tool
# ## Tool Input:
# "{\"query\": \"intermediate data science projects with python\"}"
# ## Tool Output:
# [{'query': 'intermediate data science projects with pythonsite:youtube.com', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'title': '5 Unique Python Projects (beginner to intermediate) - YouTube', 'url': 'https://www.youtube.com/watch?v=_xf1TMs0ysk', 'content': "The projects cover a variety of different topics from NFTs to games to data science! ️ NEWSLETTER: https://tinahuang.substack.com/ It's about learning, codi", 'score': 0.69870013, 'raw_content': None}, {'title': 'Python in Data Science for Intermediate - YouTube', 'url': 'https://www.youtube.com/playlist?list=PLXovS_5EZGh4_ThQVgO2boGf31Dqs5vzm', 'content': 'The Intermediate Series builds-up on the Beginner Series posted on this channel. The primary focus of these videos is to help you learn implementation of mac', 'score': 0.643173, 'raw_content': None}, {'title': 'End-to-End Data Science Projects with Python - YouTube', 'url': 'https://www.youtube.com/playlist?list=PLTsu3dft3CWg69zbIVUQtFSRx_UV80OOg', 'content': 'Welcome to my Data Science Projects playlist! In this series of videos, I explore various topics in data science and machine learning by working on hands-on', 'score': 0.6347929, 'raw_content': None}, {'title': '5 Awesome Data Science Projects Using Python - YouTube', 'url': 'https://www.youtube.com/watch?v=9QNRhSAxPjY', 'content': 'Get a look at our course on data science and AI here: 👉 https://bit.ly/3thtoUJ In this video, we are going to share with you 5 aw', 'score': 0.54201555, 'raw_content': None}, {'title': 'Mastering Python Through Projects: 20 Projects For Intermediates', 'url': 'https://www.youtube.com/watch?v=5OnI5PGSUKE', 'content': "🔥 Learn C++ and Python from Zero to Hero! 🚀Are you ready to master C++ or Python from scratch? Whether you're a beginner or looking to sharpen your skills,", 'score': 0.32830378, 'raw_content': None}], 'response_time': 2.96}, {'query': 'freeintermediate data science projects with pythonsite:udemy.com', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'title': 'Data Science Projects with Python - Udemy', 'url': 'https://www.udemy.com/course/data-science-projects-with-python/', 'content': 'Data Science Projects with Python | Udemy A case study approach to successful data science projects using Python, pandas, and scikit-learn ### Data Exploration and Cleaning 14 lectures • 1hr 32min Data Science Projects with Python is designed to give you practical guidance on industry-standard data analysis and machine learning tools in Python, with the help of realistic data. You will continue to build on your knowledge as you learn how to prepare data and feed it to machine learning algorithms, such as regularized logistic regression and random forest, using the scikit-learn package. He enjoys helping to frame problems in a data science context and delivering machine learning solutions that business stakeholders understand and value.', 'score': 0.71185225, 'raw_content': None}, {'title': 'Python Projects: Python & Data Science with Python Projects - Udemy', 'url': 'https://www.udemy.com/course/python-projects-python-data-science-with-python-projects/', 'content': 'Welcome to Python Projects: Python & Data Science with Python Projects course. Python Marathon & Data Science with NumPy, Pandas, Matplotlib, Machine Learning, Deep Learning, and Python Project. In this course, We will open the door of the Data Science world and try to move deeper.', 'score': 0.6847074, 'raw_content': None}, {'title': 'Data Science & Data Analytics Real World Projects | Udemy', 'url': 'https://www.udemy.com/course/bigdata-analysis-python/', 'content': 'Data Science & Data Analytics Real World Projects | Udemy Project 7 : Udemy Data Analysis Project 7 : Udemy Data Analysis In this comprehensive course, we present to you 9 meticulously crafted Data Analytics projects, meticulously solved using Python, a language renowned for its versatility and effectiveness in the realm of data analysis. Project 7 - Udemy Dat ...
#
#
# # Agent: Visual Learning Resources Agent
# ## Final Answer:
# {"results": [{"title": "5 Unique Python Projects (beginner to intermediate) - YouTube", "url": "https://www.youtube.com/watch?v=_xf1TMs0ysk"}, {"title": "Python in Data Science for Intermediate - YouTube", "url": "https://www.youtube.com/playlist?list=PLXovS_5EZGh4_ThQVgO2boGf31Dqs5vzm"}, {"title": "End-to-End Data Science Projects with Python - YouTube", "url": "https://www.youtube.com/playlist?list=PLTsu3dft3CWg69zbIVUQtFSRx_UV80OOg"}, {"title": "5 Awesome Data Science Projects Using Python - YouTube", "url": "https://www.youtube.com/watch?v=9QNRhSAxPjY"}, {"title": "Mastering Python Through Projects: 20 Projects For Intermediates", "url": "https://www.youtube.com/watch?v=5OnI5PGSUKE"}, {"title": "Data Science Projects with Python - Udemy", "url": "https://www.udemy.com/course/data-science-projects-with-python/"}, {"title": "Python Projects: Python & Data Science with Python Projects - Udemy", "url": "https://www.udemy.com/course/python-projects-python-data-science-with-python-projects/"}, {"title": "Data Science & Data Analytics Real World Projects | Udemy", "url": "https://www.udemy.com/course/bigdata-analysis-python/"}, {"title": "Data Analytics Real-World Projects in Python & R - Udemy", "url": "https://www.udemy.com/course/data-analytics-projects-python/"}, {"title": "Data Science Real World Projects in Python - Udemy", "url": "https://www.udemy.com/course/data-science-real-world-projects-in-python-x/"}, {"title": "Python Project for Data Science - Coursera", "url": "https://www.coursera.org/learn/python-project-for-data-science"}, {"title": "Practice Data Science Skills with Guided Projects - Coursera", "url": "https://www.coursera.org/courses?query=data+science&productTypeDescription=Guided+Projects"}, {"title": "Hands-on Data Science Projects - Coursera", "url": "https://www.coursera.org/collections/hands-on-data-science-projects"}]}
#
#
# # Agent: Search Queries Recommendation Agent
# ## Task: The user is interested in learning about: Data Science
# Their current skill level is: Intermediate (beginner, intermediate, or advanced).
# Generate up to 10 clear, focused, and diverse search queries.
# These queries should be general and not include any source/platform names (e.g., avoid YouTube, Coursera, GitHub, etc.).
# Incorporate the learning level implicitly into the query wording (e.g., 'beginner guide to ...', 'advanced concepts in ...').
# Avoid vague or overly broad phrases; be precise while keeping queries adaptable for different formats.
# Keep the phrasing natural, as a human would search in a general search engine.
#
#
# # Agent: Search Queries Recommendation Agent
# ## Final Answer:
# {
#   "queries": [
#     "intermediate data science projects using Python",
#     "practical machine learning applications in data science",
#     "advanced data visualization techniques for data science",
#     "mastering data manipulation with Pandas",
#     "building predictive models with scikit-learn: intermediate guide",
#     "handling imbalanced datasets: solutions for intermediate users",
#     "model evaluation metrics for intermediate data scientists",
#     "common pitfalls in intermediate data science projects",
#     "statistical modeling techniques for intermediate data analysis",
#     "deploying machine learning models: an intermediate approach"
#   ]
# }
#
#
# # Agent: Textual Learning Resources Agent
# ## Task: Use the available search tools to find **educational resources** related to a given query.
# Each tool searches **only within a trusted domain** (e.g., Medium, arXiv, GitHub, PapersWithCode, Distill).
# Make sure to retrieve 5 links from each website [medium.com, arxiv.org, github.com, paperswithcode.com, distill.pub]
# Focus on text-based, high-quality results such as: blog posts, technical articles, GitHub repositories, and academic papers.
# Avoid video-based content entirely (e.g., YouTube, Coursera, Udemy).
# Ensure that the results are relevant and valuable to the level of user which Intermediate
# Return **at least 5 relevant results** per query if possible.
# Each result must include a title and a working URL.
#
#
# # Agent: Textual Learning Resources Agent
# ## Thought: Thought: I need to use the text_search_tool to find relevant educational resources for each query from the provided list, focusing on medium.com, arxiv.org, github.com, paperswithcode.com, and distill.pub.  I will limit my search to text-based resources and avoid video content.  I need to retrieve at least 5 relevant results per query if possible.
# ## Using tool: text_search_tool
# ## Tool Input:
# "{\"query\": \"intermediate data science projects using Python\"}"
# ## Tool Output:
# [{'query': 'intermediate data science projects using Pythonsite:medium.com', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'title': '100 Data Science Project Ideas. Projects Across Python ... - Medium', 'url': 'https://medium.com/@mohsin.shaikh324/100-data-science-project-ideas-c987cea9660c', 'content': 'Python & Machine Learning Projects 1. Predicting House Prices with Regression Models. Develop a model using linear regression to predict house prices based on various factors like size, location', 'score': 0.7128128, 'raw_content': None}, {'title': '9 Unique Intermediate-Level Data Analytics Portfolio Project Ideas', 'url': 'https://medium.com/@annettedolph/9-unique-intermediate-level-data-analytics-portfolio-project-ideas-826915d1bace', 'content': '9 Unique Intermediate-Level Data Analytics Portfolio Project Ideas | by Annette Dolph | Medium 9 Unique Intermediate-Level Data Analytics Portfolio Project Ideas Sick of the Titanic dataset, the iris dataset, bikeshare and housing market data, and all the other common stuff beginner data analysts work on to learn? Looking for a more unique, weird, or niche data project to do for your portfolio? I’m classifying these projects as intermediate level because the projects in this list would help you boost your web scraping skills, give you experience working with unstructured or semistructured data, and potentially build, train, and refine some models. If you’re new to Medium, create a new account to read this story on us. Data And Beyond', 'score': 0.6664756, 'raw_content': None}, {'title': '170+ Data Science Projects You Can Try with Python - Medium', 'url': 'https://medium.com/@gulimran980/170-data-science-projects-you-can-try-with-python-85e91eb3cc53', 'content': 'In this article, I will introduce you to more than 180 data science and machine learning projects solved and explained using the Python programming language. Machine Learning Projects for Beginners', 'score': 0.6238588, 'raw_content': None}, {'title': '5 Intermediate Python Project Ideas that will work in the real world', 'url': 'https://callmerohit.medium.com/5-intermediate-python-project-ideas-that-will-work-in-the-real-world-d551bb3c1f48', 'content': 'Here are 5 intermediate Python project ideas that can be applied in the real world: 1. Web Scraper Create a web scraper that extracts specific data from a website. This project involves using Python libraries like requests and BeautifulSoup to send HTTP requests and parse HTML content. You can apply this project to real-world scenarios like:', 'score': 0.4889428, 'raw_content': None}, {'title': '9 Python Projects for Intermediate Python Programmers', 'url': 'https://medium.com/@helpedbyanerd/9-python-projects-for-intermediate-python-programmers-4f250d00ed7f', 'content': 'Photo by Radowan Nakif Rehan on Unsplash. The article will be divided into three categories. Automation, Web Development, and Data Science. You will find for each category 3 Python projects, that', 'score': 0.486015, 'raw_content': None}], 'response_time': 0.81}, {'query': 'intermediate data science projects using Pythonsite:arxiv.org', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'title': 'Caching and Reproducibility: Making Data Science experiments faster and ...', 'url': 'https://arxiv.org/pdf/2211.04049', 'content': 'A data science project involves exploratory data analysis, building hypotheses, performing experiments, ... (Package: R.cache4), Python (Python-memoization5), Java (JCache6, Caffeine7), which provides separate packages for caching, such as experimental states and outputs. However, extensibility of these packages in general research software', 'score': 0.22663853, 'raw_content': None}, {'title': '[2505.04080] MojoFrame: Dataframe Library in Mojo Language - arXiv.org', 'url': 'https://arxiv.org/abs/2505.04080', 'content': 'Mojo is an emerging programming language built on MLIR (Multi-Level Intermediate Representation) and JIT compilation.  ...
#
#
# # Agent: Textual Learning Resources Agent
# ## Final Answer:
# {
#   "results": [
#     {"title": "100 Data Science Project Ideas. Projects Across Python ... - Medium", "url": "https://medium.com/@mohsin.shaikh324/100-data-science-project-ideas-c987cea9660c"},
#     {"title": "9 Unique Intermediate-Level Data Analytics Portfolio Project Ideas", "url": "https://medium.com/@annettedolph/9-unique-intermediate-level-data-analytics-portfolio-project-ideas-826915d1bace"},
#     {"title": "170+ Data Science Projects You Can Try with Python - Medium", "url": "https://medium.com/@gulimran980/170-data-science-projects-you-can-try-with-python-85e91eb3cc53"},
#     {"title": "5 Intermediate Python Project Ideas that will work in the real world", "url": "https://callmerohit.medium.com/5-intermediate-python-project-ideas-that-will-work-in-the-real-world-d551bb3c1f48"},
#     {"title": "9 Python Projects for Intermediate Python Programmers", "url": "https://medium.com/@helpedbyanerd/9-python-projects-for-intermediate-python-programmers-4f250d00ed7f"},
#     {"title": "Caching and Reproducibility: Making Data Science experiments faster and ...", "url": "https://arxiv.org/pdf/2211.04049"},
#     {"title": "[2505.04080] MojoFrame: Dataframe Library in Mojo Language - arXiv.org", "url": "https://arxiv.org/abs/2505.04080"},
#     {"title": "[1911.03655] DataSist: A Python-based library for easy data analysis ...", "url": "https://arxiv.org/abs/1911.03655"},
#     {"title": "Productivity, Portability, Performance: Data-Centric Python", "url": "https://arxiv.org/pdf/2107.00555"},
#     {"title": "pyMethods2Test: A Dataset of Python Tests Mapped to Focal Methods", "url": "https://arxiv.org/html/2502.05143"},
#     {"title": "Lubula/Data-Science-Projects: intermediate python projects - GitHub", "url": "https://github.com/Lubula/Data-Science-Projects"},
#     {"title": "This project highlights intermediate data science skills ... - GitHub", "url": "https://github.com/Balisa50/statistical-data-learning"},
#     {"title": "data-science-projects-in-python · GitHub Topics · GitHub", "url": "https://github.com/topics/data-science-projects-in-python"},
#     {"title": "Intermediate Python for Data Science - GitHub", "url": "https://github.com/uc-python/intermediate-python-datasci"},
#     {"title": "veb-101/Data-Science-Projects - GitHub", "url": "https://github.com/veb-101/Data-Science-Projects"},
#     {"title": "The latest in Machine Learning | Papers With Code", "url": "https://paperswithcode.com/"},
#     {"title": "Papers with Code - Machine Learning Datasets", "url": "https://paperswithcode.com/datasets?mod=physics"},
#     {"title": "Data Science Problems Dataset - Papers With Code", "url": "https://paperswithcode.com/dataset/data-science-problems"},
#     {"title": "Papers with Code - The most popular papers with code", "url": "https://paperswithcode.com/greatest"},
#     {"title": "NICHE: A Curated Dataset of Engineered Machine Learning Projects in Python", "url": "https://paperswithcode.com/paper/niche-a-curated-dataset-of-engineered-machine"}
#   ]
# }
#
#
# # Agent: Markdown Learning Report Designer
# ## Task: Create a fully structured Markdown (.md) report file that contains all visual and textual learning resources.
# Structure should be:
# 1. Centered Title: 'Summary Report' (use markdown heading)
# 2. Visual Resources Section:
# - List each visual result from the agent (Visual Learning Resources Agent) as a bullet point like this: [Title](URL)
# 3. Textual Resources Section:
# - List each textual result from the agent (Textual Learning Resources Agent) as a bullet point like this: [Title](URL)
# Important Notes:
# - Do NOT include any HTML tags.
# - Do NOT include any code blocks like ```.
# - The file should be clean Markdown only, without any extra formatting.
#
#
# # Agent: Markdown Learning Report Designer
# ## Final Answer:
# # Summary Report
#
# ## Visual Learning Resources
#
# - [5 Unique Python Projects (beginner to intermediate) - YouTube](https://www.youtube.com/watch?v=_xf1TMs0ysk)
# - [Python in Data Science for Intermediate - YouTube](https://www.youtube.com/playlist?list=PLXovS_5EZGh4_ThQVgO2boGf31Dqs5vzm)
# - [End-to-End Data Science Projects with Python - YouTube](https://www.youtube.com/playlist?list=PLTsu3dft3CWg69zbIVUQtFSRx_UV80OOg)
# - [5 Awesome Data Science Projects Using Python - YouTube](https://www.youtube.com/watch?v=9QNRhSAxPjY)
# - [Mastering Python Through Projects: 20 Projects For Intermediates](https://www.youtube.com/watch?v=5OnI5PGSUKE)
# - [Data Science Projects with Python - Udemy](https://www.udemy.com/course/data-science-projects-with-python/)
# - [Python Projects: Python & Data Science with Python Projects - Udemy](https://www.udemy.com/course/python-projects-python-data-science-with-python-projects/)
# - [Data Science & Data Analytics Real World Projects | Udemy](https://www.udemy.com/course/bigdata-analysis-python/)
# - [Data Analytics Real-World Projects in Python & R - Udemy](https://www.udemy.com/course/data-analytics-projects-python/)
# - [Data Science Real World Projects in Python - Udemy](https://www.udemy.com/course/data-science-real-world-projects-in-python-x/)
# - [Python Project for Data Science - Coursera](https://www.coursera.org/learn/python-project-for-data-science)
# - [Practice Data Science Skills with Guided Projects - Coursera](https://www.coursera.org/courses?query=data+science&productTypeDescription=Guided+Projects)
# - [Hands-on Data Science Projects - Coursera](https://www.coursera.org/collections/hands-on-data-science-projects)
#
#
# ## Textual Learning Resources
#
# - [100 Data Science Project Ideas. Projects Across Python ... - Medium](https://medium.com/@mohsin.shaikh324/100-data-science-project-ideas-c987cea9660c)
# - [9 Unique Intermediate-Level Data Analytics Portfolio Project Ideas](https://medium.com/@annettedolph/9-unique-intermediate-level-data-analytics-portfolio-project-ideas-826915d1bace)
# - [170+ Data Science Projects You Can Try with Python - Medium](https://medium.com/@gulimran980/170-data-science-projects-you-can-try-with-python-85e91eb3cc53)
# - [5 Intermediate Python Project Ideas that will work in the real world](https://callmerohit.medium.com/5-intermediate-python-project-ideas-that-will-work-in-the-real-world-d551bb3c1f48)
# - [9 Python Projects for Intermediate Python Programmers](https://medium.com/@helpedbyanerd/9-python-projects-for-intermediate-python-programmers-4f250d00ed7f)
# - [Caching and Reproducibility: Making Data Science experiments faster and ...](https://arxiv.org/pdf/2211.04049)
# - [[2505.04080] MojoFrame: Dataframe Library in Mojo Language - arXiv.org](https://arxiv.org/abs/2505.04080)
# - [[1911.03655] DataSist: A Python-based library for easy data analysis ...](https://arxiv.org/abs/1911.03655)
# - [Productivity, Portability, Performance: Data-Centric Python](https://arxiv.org/pdf/2107.00555)
# - [pyMethods2Test: A Dataset of Python Tests Mapped to Focal Methods](https://arxiv.org/html/2502.05143)
# - [Lubula/Data-Science-Projects: intermediate python projects - GitHub](https://github.com/Lubula/Data-Science-Projects)
# - [This project highlights intermediate data science skills ... - GitHub](https://github.com/Balisa50/statistical-data-learning)
# - [data-science-projects-in-python · GitHub Topics · GitHub](https://github.com/topics/data-science-projects-in-python)
# - [Intermediate Python for Data Science - GitHub](https://github.com/uc-python/intermediate-python-datasci)
# - [veb-101/Data-Science-Projects - GitHub](https://github.com/veb-101/Data-Science-Projects)
# - [The latest in Machine Learning | Papers With Code](https://paperswithcode.com/)
# - [Papers with Code - Machine Learning Datasets](https://paperswithcode.com/datasets?mod=physics)
# - [Data Science Problems Dataset - Papers With Code](https://paperswithcode.com/dataset/data-science-problems)
# - [Papers with Code - The most popular papers with code](https://paperswithcode.com/greatest)
# - [NICHE: A Curated Dataset of Engineered Machine Learning Projects in Python](https://paperswithcode.com/paper/niche-a-curated-dataset-of-engineered-machine)
# CrewOutput(raw='# Summary Report\n\n## Visual Learning Resources\n\n- [5 Unique Python Projects (beginner to intermediate) - YouTube](https://www.youtube.com/watch?v=_xf1TMs0ysk)\n- [Python in Data Science for Intermediate - YouTube](https://www.youtube.com/playlist?list=PLXovS_5EZGh4_ThQVgO2boGf31Dqs5vzm)\n- [End-to-End Data Science Projects with Python - YouTube](https://www.youtube.com/playlist?list=PLTsu3dft3CWg69zbIVUQtFSRx_UV80OOg)\n- [5 Awesome Data Science Projects Using Python - YouTube](https://www.youtube.com/watch?v=9QNRhSAxPjY)\n- [Mastering Python Through Projects: 20 Projects For Intermediates](https://www.youtube.com/watch?v=5OnI5PGSUKE)\n- [Data Science Projects with Python - Udemy](https://www.udemy.com/course/data-science-projects-with-python/)\n- [Python Projects: Python & Data Science with Python Projects - Udemy](https://www.udemy.com/course/python-projects-python-data-science-with-python-projects/)\n- [Data Science & Data Analytics Real World Projects | Udemy](https://www.udemy.com/course/bigdata-analysis-python/)\n- [Data Analytics Real-World Projects in Python & R - Udemy](https://www.udemy.com/course/data-analytics-projects-python/)\n- [Data Science Real World Projects in Python - Udemy](https://www.udemy.com/course/data-science-real-world-projects-in-python-x/)\n- [Python Project for Data Science - Coursera](https://www.coursera.org/learn/python-project-for-data-science)\n- [Practice Data Science Skills with Guided Projects - Coursera](https://www.coursera.org/courses?query=data+science&productTypeDescription=Guided+Projects)\n- [Hands-on Data Science Projects - Coursera](https://www.coursera.org/collections/hands-on-data-science-projects)\n\n\n## Textual Learning Resources\n\n- [100 Data Science Project Ideas. Projects Across Python ... - Medium](https://medium.com/@mohsin.shaikh324/100-data-science-project-ideas-c987cea9660c)\n- [9 Unique Intermediate-Level Data Analytics Portfolio Project Ideas](https://medium.com/@annettedolph/9-unique-intermediate-level-data-analytics-portfolio-project-ideas-826915d1bace)\n- [170+ Data Science Projects You Can Try with Python - Medium](https://medium.com/@gulimran980/170-data-science-projects-you-can-try-with-python-85e91eb3cc53)\n- [5 Intermediate Python Project Ideas that will work in the real world](https://callmerohit.medium.com/5-intermediate-python-project-ideas-that-will-work-in-the-real-world-d551bb3c1f48)\n- [9 Python Projects for Intermediate Python Programmers](https://medium.com/@helpedbyanerd/9-python-projects-for-intermediate-python-programmers-4f250d00ed7f)\n- [Caching and Reproducibility: Making Data Science experiments faster and ...](https://arxiv.org/pdf/2211.04049)\n- [[2505.04080] MojoFrame: Dataframe Library in Mojo Language - arXiv.org](https://arxiv.org/abs/2505.04080)\n- [[1911.03655] DataSist: A Python-based library for easy data analysis ...](https://arxiv.org/abs/1911.03655)\n- [Productivity, Portability, Performance: Data-Centric Python](https://arxiv.org/pdf/2107.00555)\n- [pyMethods2Test: A Dataset of Python Tests Mapped to Focal Methods](https://arxiv.org/html/2502.05143)\n- [Lubula/Data-Science-Projects: intermediate python projects - GitHub](https://github.com/Lubula/Data-Science-Projects)\n- [This project highlights intermediate data science skills ... - GitHub](https://github.com/Balisa50/statistical-data-learning)\n- [data-science-projects-in-python · GitHub Topics · GitHub](https://github.com/topics/data-science-projects-in-python)\n- [Intermediate Python for Data Science - GitHub](https://github.com/uc-python/intermediate-python-datasci)\n- [veb-101/Data-Science-Projects - GitHub](https://github.com/veb-101/Data-Science-Projects)\n- [The latest in Machine Learning | Papers With Code](https://paperswithcode.com/)\n- [Papers with Code - Machine Learning Datasets](https://paperswithcode.com/datasets?mod=physics)\n- [Data Science Problems Dataset - Papers With Code](https://paperswithcode.com/dataset/data-science-problems)\n- [ ...
